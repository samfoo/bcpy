# %%
import pandas as pd
import numpy as np

# %%
evs = pd.read_parquet("events.parquet")
prs = pd.read_parquet("pairings.parquet")
pls = pd.read_parquet("placings.parquet")

# %% [markdown]
# ## Clean up/normalise events

# %%
## Clean up/normalise events

cevs = evs.copy()

# There's some non-standard countries.
cevs.loc[cevs.country == "United States", "country"] = "US"
cevs.loc[cevs.country == "United Kingdom", "country"] = "GB"
cevs.loc[cevs.country == "Argentina", "country"] = "AR"

# Not *technically* correct, because of timezones, but +/- one day for dates isn't going to matter for stats
cevs["date"] = cevs.event_date.astype("datetime64[ns, UTC]").dt.date
cevs["event_id"] = cevs.event_obj_id

cols = ["date", "name", "event_id", "number_of_rounds", "total_players", "checked_in_players", "country"]

cevs = cevs[cols]

# Drop "test" events
cevs = cevs[~cevs.name.str.match(r"[tT]est")]

# Only keep events that have more than X participants
cevs = cevs[cevs.total_players >= 4].copy()

# Only big countries
# cevs = cevs[cevs.country.isin(["ES", "US", "UK"])]
# cevs = cevs[cevs.country.isin(["PL"])]

# %%
cevs.country.unique()
# Out:
# array(['ES', 'GB', 'CZ', 'US', 'UA', 'AU', 'IT', 'LV', 'PL', 'AR', 'RU',
#        'FR', 'DE', 'CL', 'CA', 'PH', 'HU', 'MX', 'JP', 'ID', 'PE'],
#       dtype=object)

# %% [markdown]
# ## Clean up/normalise pairings

# %%
cprs = prs.copy()

# Random bogus armies
invalid_teams = ["Skittershank's Clawpack", "Servants of the Abyss"]

normal_team_changes = {
    "Adeptus Mechanicus": "Hunter Clade",
    "Adeptus Custodes": "Talons of the Emperor",
    "Astra Militarum": "Imperial Guard",
    "Kroot": "Cadre Mercenary",
    "The Gellerpox": "Gellerpox Infected",
    "Starstriders": "Elucidian Starstriders",
    "Daemons": "Chaos Daemons",
    "Deathwatch": "Space Marine",
    "Adeptus Astartes": "Space Marine",
    "T'au Empire": "Hunter Cadre",
    "Kroot Mercenaries": "Cadre Mercenary",
    "Farstalker Kinblade": "Farstalker Kinband",
    "Kroot Farstalker Kinband": "Farstalker Kinband",
    "Necrons": "Tomb World",
    "Tyranids": "Hive Fleet",
    "Ork Kommandos": "Kommando",
    "Navis Breachers": "Imperial Navy Breachers",
    "Adepta Sororitas": "Ecclesiarchy",
    "Harlequins": "Void-Dancer Troupe",
    "Drukhari": "Commorite",
    "Thousand Sons": "Warp Coven",
    "Orks": "Greenskin",
    "Genestealer Cults": "Brood Coven",
    "Asuryani": "Craftworld",
    "Heretic Astartes": "Traitor Space Marine",
}

bespoke_teams = [
    "Legionary",
    "Corsair Voidscarred",
    "Intercession Squad",
    "Pathfinders",
    "Wyrmblade",
    "Imperial Navy Breachers",
    "Gellerpox Infected",
    "Veteran Guardsmen",
    "Phobos Strike Team",
    "Void-Dancer Troupe",
    "Hunter Clade",
    "Novitiates",
    "Blooded Traitors",
    "Kommando",
    "Elucidian Starstriders",
    "Hierotek Circle",
    "Warp Coven",
    "Farstalker Kinband",
    "Kasrkin",
]

cprs = cprs[(~cprs.player1_army.isin(invalid_teams)) & (~cprs.player2_army.isin(invalid_teams))]

for p in ["player1", "player2"]:
    cprs[f"{p}_army"] = cprs[f"{p}_army"].str.strip()
    cprs[f"{p}_army"] = cprs[f"{p}_army"].replace(normal_team_changes)

cprs = cprs[cprs.event_id.isin(cevs.event_id.unique())]
cprs = cprs[cprs.player1_army.notnull() & cprs.player2_army.notnull()]

#### Add event date, and clean anything else up
cprs = cprs.merge(cevs[["date", "country", "event_id"]], on="event_id", how="left")
cprs["month"] = cprs.date.apply(lambda d: "%04d-%02d" % (d.year, d.month))

#### Fix BCP's issue where old teams get changed to bespoke ones
for p in ["player1", "player2"]:
    cprs.loc[(cprs[f"{p}_army"] == "Intercession Squad") & (cprs.month < "2022-08"), f"{p}_army"] = "Space Marine"
    cprs.loc[(cprs[f"{p}_army"] == "Void-Dancer Troupe") & (cprs.month < "2022-04"), f"{p}_army"] = "Troupe"
    cprs.loc[(cprs[f"{p}_army"] == "Warp Coven") & (cprs.month < "2022-04"), f"{p}_army"] = "Traitor Space Marine"

# %% [markdown]
# ## Meta representation
#
# Meta representation is defined as the number of distinct (player, competition, team) tuples. In other words: The number of times a team was chosen for tournaments.
#
# The downside of this approach is that small tournaments can skew the meta representation, but I think this is better than the alternative where large tournaments with many rounds of play skew the results.

# %%
#### 1. Explode the player1/player2 representation so each player/army/tournament is a single row
p1_mrep = cprs.groupby(["event_id", "month", "player1_user_id", "player1_army"]).first().reset_index().rename(columns={"player1_user_id": "user_id", "player1_army": "army"})
p2_mrep = cprs.groupby(["event_id", "month", "player2_user_id", "player2_army"]).first().reset_index().rename(columns={"player2_user_id": "user_id", "player2_army": "army"})

mrep = pd.concat([p1_mrep, p2_mrep], ignore_index=True)[["event_id", "month", "user_id", "army"]]

#### 2. Weight by (tournament, player, army)
mrep = mrep.drop_duplicates()
mrep["is_bespoke"] = mrep.army.isin(bespoke_teams)

# %%
def display_meta_rep(mrr):
    mr = mrr.groupby(["month", "army"]).size().reset_index().rename(columns={0: "event_takes"})
    mr = mr.sort_values("event_takes", ascending=False)
    mr = mr.pivot(index="army", columns="month", values="event_takes").fillna(0).astype("int32")
    mr = mr.div(mr.sum(axis=0))
    mr = mr.sort_values(mr.columns[-1], ascending=False)

    return mr.style.background_gradient(cmap='Purples').format({c: '{:.2%}' for c in mr.columns})

# %% [markdown]
# #### All Armies

# %%
display_meta_rep(mrep)
# Out:
# <style type="text/css">
# #T_a2544_row0_col0, #T_a2544_row0_col1, #T_a2544_row0_col2, #T_a2544_row0_col3, #T_a2544_row0_col4, #T_a2544_row0_col5, #T_a2544_row0_col6, #T_a2544_row0_col7, #T_a2544_row1_col0, #T_a2544_row1_col1, #T_a2544_row1_col2, #T_a2544_row1_col3, #T_a2544_row5_col0, #T_a2544_row5_col1, #T_a2544_row5_col2, #T_a2544_row5_col3, #T_a2544_row5_col4, #T_a2544_row5_col5, #T_a2544_row5_col6, #T_a2544_row5_col7, #T_a2544_row6_col0, #T_a2544_row6_col1, #T_a2544_row6_col2, #T_a2544_row6_col3, #T_a2544_row7_col0, #T_a2544_row7_col1, #T_a2544_row7_col2, #T_a2544_row7_col3, #T_a2544_row10_col0, #T_a2544_row10_col1, #T_a2544_row10_col2, #T_a2544_row10_col3, #T_a2544_row10_col4, #T_a2544_row10_col5, #T_a2544_row10_col7, #T_a2544_row11_col0, #T_a2544_row11_col1, #T_a2544_row11_col2, #T_a2544_row12_col0, #T_a2544_row12_col1, #T_a2544_row12_col2, #T_a2544_row14_col0, #T_a2544_row14_col1, #T_a2544_row14_col2, #T_a2544_row14_col3, #T_a2544_row14_col4, #T_a2544_row15_col0, #T_a2544_row15_col1, #T_a2544_row15_col2, #T_a2544_row15_col3, #T_a2544_row15_col4, #T_a2544_row15_col5, #T_a2544_row15_col6, #T_a2544_row15_col7, #T_a2544_row20_col0, #T_a2544_row20_col1, #T_a2544_row20_col2, #T_a2544_row20_col3, #T_a2544_row20_col4, #T_a2544_row20_col5, #T_a2544_row20_col6, #T_a2544_row20_col7, #T_a2544_row21_col0, #T_a2544_row21_col1, #T_a2544_row21_col2, #T_a2544_row21_col3, #T_a2544_row21_col4, #T_a2544_row21_col5, #T_a2544_row21_col6, #T_a2544_row21_col7, #T_a2544_row21_col8, #T_a2544_row29_col7, #T_a2544_row31_col6, #T_a2544_row32_col2, #T_a2544_row32_col4, #T_a2544_row32_col6, #T_a2544_row32_col7, #T_a2544_row32_col8, #T_a2544_row33_col0, #T_a2544_row33_col1, #T_a2544_row33_col2, #T_a2544_row33_col3, #T_a2544_row33_col4, #T_a2544_row33_col5, #T_a2544_row33_col6, #T_a2544_row33_col7, #T_a2544_row33_col8, #T_a2544_row34_col5, #T_a2544_row34_col7, #T_a2544_row34_col8, #T_a2544_row34_col9, #T_a2544_row35_col3, #T_a2544_row35_col5, #T_a2544_row35_col8, #T_a2544_row35_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_a2544_row0_col8, #T_a2544_row4_col4 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_a2544_row0_col9, #T_a2544_row1_col5, #T_a2544_row1_col6, #T_a2544_row1_col7, #T_a2544_row1_col8, #T_a2544_row3_col4, #T_a2544_row4_col0, #T_a2544_row4_col2, #T_a2544_row4_col3, #T_a2544_row31_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_a2544_row1_col4, #T_a2544_row8_col3, #T_a2544_row34_col3 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_a2544_row1_col9 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_a2544_row2_col0, #T_a2544_row23_col0, #T_a2544_row28_col6 {
#   background-color: #e8e6f2;
#   color: #000000;
# }
# #T_a2544_row2_col1 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_a2544_row2_col2, #T_a2544_row17_col2, #T_a2544_row18_col5, #T_a2544_row22_col1, #T_a2544_row26_col5, #T_a2544_row35_col0 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_a2544_row2_col3, #T_a2544_row12_col3, #T_a2544_row28_col3 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_a2544_row2_col4, #T_a2544_row11_col3, #T_a2544_row19_col1, #T_a2544_row24_col0 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_a2544_row2_col5, #T_a2544_row7_col5, #T_a2544_row28_col5 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_a2544_row2_col6, #T_a2544_row13_col7 {
#   background-color: #9f9cc9;
#   color: #f1f1f1;
# }
# #T_a2544_row2_col7 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_a2544_row2_col8, #T_a2544_row13_col6 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_a2544_row2_col9 {
#   background-color: #b7b7d9;
#   color: #000000;
# }
# #T_a2544_row3_col0 {
#   background-color: #6b53a4;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col1 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col2 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col3 {
#   background-color: #460c83;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col5, #T_a2544_row12_col5 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col6 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_a2544_row3_col7, #T_a2544_row8_col7, #T_a2544_row12_col7 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_a2544_row3_col8, #T_a2544_row17_col0, #T_a2544_row27_col0 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_a2544_row3_col9, #T_a2544_row4_col9, #T_a2544_row5_col9, #T_a2544_row19_col2 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_a2544_row4_col1, #T_a2544_row19_col4 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_a2544_row4_col5 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_a2544_row4_col6 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# #T_a2544_row4_col7 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_a2544_row4_col8 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_a2544_row5_col8, #T_a2544_row18_col6, #T_a2544_row26_col6 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_a2544_row6_col4, #T_a2544_row13_col1, #T_a2544_row19_col5, #T_a2544_row26_col0, #T_a2544_row31_col4 {
#   background-color: #bfc0de;
#   color: #000000;
# }
# #T_a2544_row6_col5, #T_a2544_row14_col5 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_a2544_row6_col6 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_a2544_row6_col7, #T_a2544_row29_col3 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_a2544_row6_col8 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_a2544_row6_col9 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_a2544_row7_col4, #T_a2544_row27_col8, #T_a2544_row31_col5, #T_a2544_row35_col2, #T_a2544_row35_col4 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_a2544_row7_col6, #T_a2544_row16_col8, #T_a2544_row18_col7, #T_a2544_row24_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_a2544_row7_col7, #T_a2544_row22_col7 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_a2544_row7_col8, #T_a2544_row18_col8, #T_a2544_row19_col6, #T_a2544_row19_col8, #T_a2544_row24_col8, #T_a2544_row25_col6 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_a2544_row7_col9, #T_a2544_row8_col9 {
#   background-color: #cecee5;
#   color: #000000;
# }
# #T_a2544_row8_col0, #T_a2544_row16_col5 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col1 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col2 {
#   background-color: #9c98c7;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col4 {
#   background-color: #6f5ba8;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col5, #T_a2544_row9_col5 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col6, #T_a2544_row22_col5, #T_a2544_row34_col0 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_a2544_row8_col8 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_a2544_row9_col0, #T_a2544_row25_col5, #T_a2544_row28_col0, #T_a2544_row29_col5, #T_a2544_row30_col5 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_a2544_row9_col1 {
#   background-color: #7465ad;
#   color: #f1f1f1;
# }
# #T_a2544_row9_col2 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_a2544_row9_col3 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_a2544_row9_col4 {
#   background-color: #7262ac;
#   color: #f1f1f1;
# }
# #T_a2544_row9_col6 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_a2544_row9_col7 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_a2544_row9_col8 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_a2544_row9_col9 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_a2544_row10_col6, #T_a2544_row15_col8, #T_a2544_row23_col7, #T_a2544_row30_col6, #T_a2544_row30_col7, #T_a2544_row30_col8, #T_a2544_row30_col9, #T_a2544_row31_col8, #T_a2544_row31_col9, #T_a2544_row32_col1, #T_a2544_row32_col9, #T_a2544_row33_col9, #T_a2544_row35_col6, #T_a2544_row35_col7 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_a2544_row10_col8, #T_a2544_row26_col8 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_a2544_row10_col9, #T_a2544_row11_col9 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_a2544_row11_col4, #T_a2544_row22_col4 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_a2544_row11_col5 {
#   back

# %% [markdown]
# #### Bespoke Only

# %%
display_meta_rep(mrep[mrep.is_bespoke])
# Out:
# <style type="text/css">
# #T_a144c_row0_col0, #T_a144c_row0_col1, #T_a144c_row0_col2, #T_a144c_row0_col3, #T_a144c_row0_col4, #T_a144c_row0_col5, #T_a144c_row0_col6, #T_a144c_row0_col7, #T_a144c_row1_col0, #T_a144c_row1_col1, #T_a144c_row1_col2, #T_a144c_row1_col3, #T_a144c_row5_col0, #T_a144c_row5_col1, #T_a144c_row5_col2, #T_a144c_row5_col3, #T_a144c_row5_col4, #T_a144c_row5_col5, #T_a144c_row5_col6, #T_a144c_row5_col7, #T_a144c_row6_col0, #T_a144c_row6_col1, #T_a144c_row6_col2, #T_a144c_row6_col3, #T_a144c_row7_col0, #T_a144c_row7_col1, #T_a144c_row7_col2, #T_a144c_row7_col3, #T_a144c_row10_col0, #T_a144c_row10_col1, #T_a144c_row10_col2, #T_a144c_row10_col3, #T_a144c_row10_col4, #T_a144c_row10_col5, #T_a144c_row10_col7, #T_a144c_row11_col0, #T_a144c_row11_col1, #T_a144c_row11_col2, #T_a144c_row12_col0, #T_a144c_row12_col1, #T_a144c_row12_col2, #T_a144c_row14_col0, #T_a144c_row14_col1, #T_a144c_row14_col2, #T_a144c_row14_col3, #T_a144c_row14_col4, #T_a144c_row15_col0, #T_a144c_row15_col1, #T_a144c_row15_col2, #T_a144c_row15_col3, #T_a144c_row15_col4, #T_a144c_row15_col5, #T_a144c_row15_col6, #T_a144c_row15_col7, #T_a144c_row16_col0, #T_a144c_row16_col1, #T_a144c_row16_col2, #T_a144c_row16_col3, #T_a144c_row16_col4, #T_a144c_row16_col5, #T_a144c_row16_col6, #T_a144c_row16_col7, #T_a144c_row17_col0, #T_a144c_row17_col1, #T_a144c_row17_col2, #T_a144c_row17_col3, #T_a144c_row17_col4, #T_a144c_row17_col5, #T_a144c_row17_col6, #T_a144c_row17_col7, #T_a144c_row17_col8, #T_a144c_row18_col0, #T_a144c_row18_col1, #T_a144c_row18_col2, #T_a144c_row18_col3, #T_a144c_row18_col4, #T_a144c_row18_col5, #T_a144c_row18_col6, #T_a144c_row18_col7, #T_a144c_row18_col8, #T_a144c_row18_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_a144c_row0_col8, #T_a144c_row4_col4 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_a144c_row0_col9, #T_a144c_row1_col5, #T_a144c_row1_col6, #T_a144c_row1_col7, #T_a144c_row1_col8, #T_a144c_row3_col1, #T_a144c_row3_col4, #T_a144c_row4_col0, #T_a144c_row4_col2, #T_a144c_row4_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_a144c_row1_col4, #T_a144c_row8_col3 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_a144c_row1_col9 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_a144c_row2_col0 {
#   background-color: #e8e6f2;
#   color: #000000;
# }
# #T_a144c_row2_col1 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_a144c_row2_col2 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_a144c_row2_col3, #T_a144c_row12_col3 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_a144c_row2_col4, #T_a144c_row11_col3 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_a144c_row2_col5, #T_a144c_row7_col5 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_a144c_row2_col6, #T_a144c_row13_col7 {
#   background-color: #9f9cc9;
#   color: #f1f1f1;
# }
# #T_a144c_row2_col7 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_a144c_row2_col8, #T_a144c_row13_col6 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_a144c_row2_col9, #T_a144c_row14_col7 {
#   background-color: #b8b8d9;
#   color: #000000;
# }
# #T_a144c_row3_col0 {
#   background-color: #6b53a4;
#   color: #f1f1f1;
# }
# #T_a144c_row3_col2 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_a144c_row3_col3 {
#   background-color: #460c83;
#   color: #f1f1f1;
# }
# #T_a144c_row3_col5, #T_a144c_row12_col5 {
#   background-color: #5c3696;
#   color: #f1f1f1;
# }
# #T_a144c_row3_col6 {
#   background-color: #9692c4;
#   color: #f1f1f1;
# }
# #T_a144c_row3_col7, #T_a144c_row8_col7, #T_a144c_row12_col7 {
#   background-color: #b4b4d7;
#   color: #000000;
# }
# #T_a144c_row3_col8 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_a144c_row3_col9, #T_a144c_row4_col9, #T_a144c_row5_col9, #T_a144c_row6_col4 {
#   background-color: #bfc0de;
#   color: #000000;
# }
# #T_a144c_row4_col1, #T_a144c_row12_col6 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_a144c_row4_col5 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_a144c_row4_col6 {
#   background-color: #807dba;
#   color: #f1f1f1;
# }
# #T_a144c_row4_col7 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_a144c_row4_col8 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_a144c_row5_col8 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_a144c_row6_col5, #T_a144c_row14_col5 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_a144c_row6_col6 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_a144c_row6_col7 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_a144c_row6_col8 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_a144c_row6_col9 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_a144c_row7_col4 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_a144c_row7_col6 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_a144c_row7_col7 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_a144c_row7_col8 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_a144c_row7_col9, #T_a144c_row8_col9, #T_a144c_row9_col8 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_a144c_row8_col0 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col1 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col2 {
#   background-color: #9c98c7;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col4 {
#   background-color: #6f5ba8;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col5, #T_a144c_row9_col5 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col6 {
#   background-color: #8784bd;
#   color: #f1f1f1;
# }
# #T_a144c_row8_col8 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_a144c_row9_col0 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_a144c_row9_col1 {
#   background-color: #62429c;
#   color: #f1f1f1;
# }
# #T_a144c_row9_col2 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_a144c_row9_col3 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_a144c_row9_col4 {
#   background-color: #7262ac;
#   color: #f1f1f1;
# }
# #T_a144c_row9_col6 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_a144c_row9_col7 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_a144c_row9_col9 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_a144c_row10_col6, #T_a144c_row15_col8 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_a144c_row10_col8 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_a144c_row10_col9, #T_a144c_row11_col9 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# #T_a144c_row11_col4 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_a144c_row11_col5 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_a144c_row11_col6 {
#   background-color: #d8d8ea;
#   color: #000000;
# }
# #T_a144c_row11_col7 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_a144c_row11_col8 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_a144c_row12_col4 {
#   background-color: #7d78b7;
#   color: #f1f1f1;
# }
# #T_a144c_row12_col8 {
#   background-color: #cdcde4;
#   color: #000000;
# }
# #T_a144c_row12_col9 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_a144c_row13_col0 {
#   background-color: #a09dca;
#   color: #f1f1f1;
# }
# #T_a144c_row13_col1 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_a144c_row13_col2 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_a144c_row13_col3 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_a144c_row13_col4 {
#   background-color: #817ebb;
#   color: #f1f1f1;
# }
# #T_a144c_row13_col5 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# #T_a144c_row13_col8, #T_a144c_row14_col8 {
#   background-color: #c7c8e1;
#   color: #000000;
# }
# #T_a144c_row13_col9 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_a144c_row14_col6 {
#   background-color: #7970b3;
#   color: #f1f1f1;
# }
# #T_a144c_row14_col9 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_a144c_row15_col9 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_a144c_row16_col8 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_a144c_row16_col9 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_a144c_row17_col9 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# </style>
# <table id="T_a144c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th id="T_a144c_level0_col0" clas

# %% [markdown]
# #### Compendium Only

# %%
display_meta_rep(mrep[~mrep.is_bespoke])
# Out:
# <style type="text/css">
# #T_e7bc2_row0_col0 {
#   background-color: #aba9d0;
#   color: #000000;
# }
# #T_e7bc2_row0_col1 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_e7bc2_row0_col2 {
#   background-color: #c3c4e0;
#   color: #000000;
# }
# #T_e7bc2_row0_col3, #T_e7bc2_row6_col4 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_e7bc2_row0_col4, #T_e7bc2_row0_col7, #T_e7bc2_row0_col9, #T_e7bc2_row4_col5, #T_e7bc2_row4_col6, #T_e7bc2_row4_col8, #T_e7bc2_row12_col0, #T_e7bc2_row12_col1, #T_e7bc2_row12_col2, #T_e7bc2_row12_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_e7bc2_row0_col5 {
#   background-color: #4b1687;
#   color: #f1f1f1;
# }
# #T_e7bc2_row0_col6, #T_e7bc2_row6_col6 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_e7bc2_row0_col8, #T_e7bc2_row16_col3 {
#   background-color: #5d3897;
#   color: #f1f1f1;
# }
# #T_e7bc2_row1_col0 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_e7bc2_row1_col1 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_e7bc2_row1_col2 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_e7bc2_row1_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e7bc2_row1_col4, #T_e7bc2_row10_col4 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_e7bc2_row1_col5, #T_e7bc2_row10_col5, #T_e7bc2_row13_col4, #T_e7bc2_row16_col4 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_e7bc2_row1_col6, #T_e7bc2_row10_col6 {
#   background-color: #7566ae;
#   color: #f1f1f1;
# }
# #T_e7bc2_row1_col7, #T_e7bc2_row6_col0 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_e7bc2_row1_col8, #T_e7bc2_row3_col8, #T_e7bc2_row6_col8 {
#   background-color: #7261ab;
#   color: #f1f1f1;
# }
# #T_e7bc2_row1_col9, #T_e7bc2_row2_col9 {
#   background-color: #5b3495;
#   color: #f1f1f1;
# }
# #T_e7bc2_row2_col0, #T_e7bc2_row8_col0 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_e7bc2_row2_col1, #T_e7bc2_row10_col1 {
#   background-color: #e8e6f2;
#   color: #000000;
# }
# #T_e7bc2_row2_col2, #T_e7bc2_row8_col1 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_e7bc2_row2_col3, #T_e7bc2_row2_col7, #T_e7bc2_row6_col7, #T_e7bc2_row10_col7 {
#   background-color: #dfdfed;
#   color: #000000;
# }
# #T_e7bc2_row2_col4, #T_e7bc2_row3_col5 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_e7bc2_row2_col5 {
#   background-color: #b8b8d9;
#   color: #000000;
# }
# #T_e7bc2_row2_col6, #T_e7bc2_row8_col6 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_e7bc2_row2_col8, #T_e7bc2_row5_col8, #T_e7bc2_row7_col8 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_e7bc2_row3_col0, #T_e7bc2_row11_col4 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_e7bc2_row3_col1 {
#   background-color: #cccce4;
#   color: #000000;
# }
# #T_e7bc2_row3_col2, #T_e7bc2_row6_col5 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_e7bc2_row3_col3 {
#   background-color: #9c98c7;
#   color: #f1f1f1;
# }
# #T_e7bc2_row3_col4 {
#   background-color: #51218c;
#   color: #f1f1f1;
# }
# #T_e7bc2_row3_col6, #T_e7bc2_row9_col6 {
#   background-color: #807cba;
#   color: #f1f1f1;
# }
# #T_e7bc2_row3_col7 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_e7bc2_row3_col9 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_e7bc2_row4_col0 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_e7bc2_row4_col1, #T_e7bc2_row7_col3, #T_e7bc2_row9_col8, #T_e7bc2_row11_col8 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_e7bc2_row4_col2 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_e7bc2_row4_col3, #T_e7bc2_row8_col3 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_e7bc2_row4_col4 {
#   background-color: #63449d;
#   color: #f1f1f1;
# }
# #T_e7bc2_row4_col7 {
#   background-color: #adabd2;
#   color: #000000;
# }
# #T_e7bc2_row4_col9, #T_e7bc2_row5_col9 {
#   background-color: #8a86bf;
#   color: #f1f1f1;
# }
# #T_e7bc2_row5_col0, #T_e7bc2_row8_col7 {
#   background-color: #eae8f2;
#   color: #000000;
# }
# #T_e7bc2_row5_col1, #T_e7bc2_row11_col1, #T_e7bc2_row15_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_e7bc2_row5_col2, #T_e7bc2_row12_col8, #T_e7bc2_row13_col8 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_e7bc2_row5_col3 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_e7bc2_row5_col4, #T_e7bc2_row14_col5 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_e7bc2_row5_col5 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_e7bc2_row5_col6, #T_e7bc2_row16_col6 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_e7bc2_row5_col7, #T_e7bc2_row13_col7, #T_e7bc2_row15_col7 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_e7bc2_row6_col1, #T_e7bc2_row7_col2, #T_e7bc2_row9_col4, #T_e7bc2_row9_col5, #T_e7bc2_row11_col5, #T_e7bc2_row13_col5 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_e7bc2_row6_col2 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_e7bc2_row6_col3, #T_e7bc2_row11_col2 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_e7bc2_row6_col9 {
#   background-color: #b2b2d5;
#   color: #000000;
# }
# #T_e7bc2_row7_col0 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_e7bc2_row7_col1, #T_e7bc2_row8_col4, #T_e7bc2_row8_col5, #T_e7bc2_row13_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_e7bc2_row7_col4, #T_e7bc2_row7_col5, #T_e7bc2_row7_col7, #T_e7bc2_row9_col7, #T_e7bc2_row11_col6, #T_e7bc2_row11_col9 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_e7bc2_row7_col6 {
#   background-color: #5e3b98;
#   color: #f1f1f1;
# }
# #T_e7bc2_row7_col9, #T_e7bc2_row8_col9, #T_e7bc2_row9_col9, #T_e7bc2_row10_col9 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_e7bc2_row8_col2 {
#   background-color: #d7d7e9;
#   color: #000000;
# }
# #T_e7bc2_row8_col8 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_e7bc2_row9_col0, #T_e7bc2_row13_col0 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_e7bc2_row9_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_e7bc2_row9_col2, #T_e7bc2_row13_col2 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_e7bc2_row9_col3, #T_e7bc2_row12_col7, #T_e7bc2_row13_col3, #T_e7bc2_row13_col6, #T_e7bc2_row15_col6 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_e7bc2_row10_col0 {
#   background-color: #b7b7d9;
#   color: #000000;
# }
# #T_e7bc2_row10_col2 {
#   background-color: #cdcde4;
#   color: #000000;
# }
# #T_e7bc2_row10_col3 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_e7bc2_row10_col8 {
#   background-color: #53258e;
#   color: #f1f1f1;
# }
# #T_e7bc2_row11_col0 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_e7bc2_row11_col3 {
#   background-color: #b0afd4;
#   color: #000000;
# }
# #T_e7bc2_row11_col7, #T_e7bc2_row12_col6, #T_e7bc2_row14_col0, #T_e7bc2_row14_col1, #T_e7bc2_row14_col2, #T_e7bc2_row14_col4, #T_e7bc2_row14_col6, #T_e7bc2_row14_col7, #T_e7bc2_row14_col8, #T_e7bc2_row15_col3, #T_e7bc2_row15_col5, #T_e7bc2_row15_col8, #T_e7bc2_row15_col9, #T_e7bc2_row16_col5, #T_e7bc2_row16_col7, #T_e7bc2_row16_col8, #T_e7bc2_row16_col9 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_e7bc2_row12_col4 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_e7bc2_row12_col5, #T_e7bc2_row15_col4 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_e7bc2_row12_col9, #T_e7bc2_row13_col9, #T_e7bc2_row14_col9 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_e7bc2_row14_col3 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_e7bc2_row15_col0 {
#   background-color: #e5e4f0;
#   color: #000000;
# }
# #T_e7bc2_row15_col2 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_e7bc2_row16_col0 {
#   background-color: #7567af;
#   color: #f1f1f1;
# }
# #T_e7bc2_row16_col1 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_e7bc2_row16_col2 {
#   background-color: #7b72b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7bc2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th id="T_e7bc2_level0_col0" class="col_heading level0 col0" >2022-01</th>
#       <th id="T_e7bc2_level0_col1" class="col_heading level0 col1" >2022-02</th>
#       <th id="T_e7bc2_level0_col2" class="col_heading level0 col2" >2022-03</th>
#       <th id="T_e7bc2_level0_col3" class="col_heading level0 col3" >2022-04</th>
#       <th id="T_e7bc2_level0_col4" class="col_heading level0 col4" >2022-05</th>

# %% [markdown]
# ## Win Rate

# %%
nm_ms = cprs[cprs.player1_army != cprs.player2_army]

p1_rs = nm_ms[["event_id", "month", "player1_army", "player1_game_result_cat"]].rename(columns={"player1_army": "army", "player1_game_result_cat": "result"})
p2_rs = nm_ms[["event_id", "month", "player2_army", "player2_game_result_cat"]].rename(columns={"player2_army": "army", "player2_game_result_cat": "result"})

w_rs = pd.concat([p1_rs, p2_rs], ignore_index=True)
w_rs["is_bespoke"] = w_rs.army.isin(bespoke_teams)

# %%
def display_win_rates(rs):
    rs = rs.groupby(["month", "army", "result"]).size().reset_index().rename(columns={0: "outcomes"})
    rs = rs.pivot(index=["month", "army"], columns="result", values="outcomes").fillna(0).astype("int32")
    rs["matches"] = rs.loss + rs.tie + rs.win
    
    rs = rs[rs.matches > 10]
    rs["win_rate"] = rs.win.astype("float64") / rs.matches
    rs = rs.reset_index()
    rs = rs.pivot(index="army", columns="month", values="win_rate").fillna(0)
    
    rs = rs.sort_values(rs.columns[-1], ascending=False)
    
    return rs.style.background_gradient(cmap="Blues").format({c: '{:.2%}' for c in rs.columns})

# %%
display_win_rates(w_rs[w_rs.is_bespoke])
# Out:
# <style type="text/css">
# #T_f0b7e_row0_col0, #T_f0b7e_row0_col1, #T_f0b7e_row0_col2, #T_f0b7e_row0_col3, #T_f0b7e_row0_col4, #T_f0b7e_row0_col5, #T_f0b7e_row0_col6, #T_f0b7e_row0_col7, #T_f0b7e_row1_col0, #T_f0b7e_row1_col1, #T_f0b7e_row1_col2, #T_f0b7e_row1_col3, #T_f0b7e_row1_col4, #T_f0b7e_row1_col5, #T_f0b7e_row1_col6, #T_f0b7e_row1_col7, #T_f0b7e_row2_col0, #T_f0b7e_row2_col1, #T_f0b7e_row2_col2, #T_f0b7e_row4_col0, #T_f0b7e_row4_col1, #T_f0b7e_row4_col2, #T_f0b7e_row4_col3, #T_f0b7e_row4_col4, #T_f0b7e_row6_col0, #T_f0b7e_row6_col1, #T_f0b7e_row6_col2, #T_f0b7e_row6_col3, #T_f0b7e_row7_col0, #T_f0b7e_row7_col1, #T_f0b7e_row7_col2, #T_f0b7e_row7_col3, #T_f0b7e_row7_col4, #T_f0b7e_row7_col5, #T_f0b7e_row7_col6, #T_f0b7e_row7_col7, #T_f0b7e_row8_col0, #T_f0b7e_row8_col1, #T_f0b7e_row8_col2, #T_f0b7e_row8_col3, #T_f0b7e_row11_col0, #T_f0b7e_row11_col1, #T_f0b7e_row11_col2, #T_f0b7e_row12_col0, #T_f0b7e_row14_col0, #T_f0b7e_row14_col1, #T_f0b7e_row14_col2, #T_f0b7e_row14_col3, #T_f0b7e_row14_col4, #T_f0b7e_row14_col5, #T_f0b7e_row14_col6, #T_f0b7e_row14_col7, #T_f0b7e_row15_col0, #T_f0b7e_row15_col1, #T_f0b7e_row15_col2, #T_f0b7e_row15_col3, #T_f0b7e_row15_col4, #T_f0b7e_row16_col0, #T_f0b7e_row16_col1, #T_f0b7e_row16_col2, #T_f0b7e_row16_col3, #T_f0b7e_row16_col4, #T_f0b7e_row16_col5, #T_f0b7e_row16_col6, #T_f0b7e_row16_col7, #T_f0b7e_row16_col8, #T_f0b7e_row17_col0, #T_f0b7e_row17_col1, #T_f0b7e_row17_col2, #T_f0b7e_row17_col3, #T_f0b7e_row17_col4, #T_f0b7e_row17_col5, #T_f0b7e_row17_col6, #T_f0b7e_row17_col7, #T_f0b7e_row17_col8, #T_f0b7e_row17_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f0b7e_row0_col8, #T_f0b7e_row12_col7 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_f0b7e_row0_col9, #T_f0b7e_row1_col8, #T_f0b7e_row2_col3, #T_f0b7e_row2_col4, #T_f0b7e_row2_col5, #T_f0b7e_row10_col0, #T_f0b7e_row10_col1, #T_f0b7e_row10_col2, #T_f0b7e_row10_col6, #T_f0b7e_row10_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f0b7e_row1_col9, #T_f0b7e_row9_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_f0b7e_row2_col6 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_f0b7e_row2_col7 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_f0b7e_row2_col8 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_f0b7e_row2_col9 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_f0b7e_row3_col4 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col5 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col6, #T_f0b7e_row6_col6, #T_f0b7e_row12_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col7, #T_f0b7e_row13_col8 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col8, #T_f0b7e_row10_col8 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_f0b7e_row3_col9 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_f0b7e_row4_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_f0b7e_row4_col6, #T_f0b7e_row9_col5 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_f0b7e_row4_col7, #T_f0b7e_row4_col8, #T_f0b7e_row5_col4, #T_f0b7e_row5_col7 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_f0b7e_row4_col9, #T_f0b7e_row8_col5, #T_f0b7e_row12_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col1, #T_f0b7e_row13_col4 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col2, #T_f0b7e_row6_col8, #T_f0b7e_row9_col6, #T_f0b7e_row12_col2 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col5, #T_f0b7e_row15_col5 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col6, #T_f0b7e_row6_col4 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col8 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_f0b7e_row5_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_f0b7e_row6_col5 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_f0b7e_row6_col7, #T_f0b7e_row14_col8 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_f0b7e_row6_col9 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_f0b7e_row7_col8, #T_f0b7e_row12_col5, #T_f0b7e_row13_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_f0b7e_row7_col9 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_f0b7e_row8_col4 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_f0b7e_row8_col6, #T_f0b7e_row9_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_f0b7e_row8_col7 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_f0b7e_row8_col8 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_f0b7e_row8_col9 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col3 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col4 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col7, #T_f0b7e_row11_col7 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col8 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_f0b7e_row9_col9 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_f0b7e_row10_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_f0b7e_row10_col4 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_f0b7e_row10_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_f0b7e_row10_col9 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_f0b7e_row11_col3, #T_f0b7e_row11_col8 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_f0b7e_row11_col4, #T_f0b7e_row15_col8 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_f0b7e_row11_col5, #T_f0b7e_row13_col6 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_f0b7e_row11_col6 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_f0b7e_row11_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_f0b7e_row12_col4, #T_f0b7e_row13_col1, #T_f0b7e_row13_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_f0b7e_row12_col6 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_f0b7e_row12_col8 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_f0b7e_row12_col9 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_f0b7e_row13_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_f0b7e_row13_col5 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_f0b7e_row13_col7 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_f0b7e_row13_col9 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_f0b7e_row14_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f0b7e_row15_col6 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_f0b7e_row15_col7 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_f0b7e_row15_col9 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f0b7e_row16_col9 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_f0b7e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th id="T_f0b7e_level0_col0" class="col_heading level0 col0" >2022-01</th>
#       <th id="T_f0b7e_level0_col1" class="col_heading level0 col1" >2022-02</th>
#       <th id="T_f0b7e_level0_col2" class="col_heading level0 col2" >2022-03</th>
#       <th id="T_f0b7e_level0_col3" class="col_heading level0 col3" >2022-04</th>
#       <th id="T_f0b7e_level0_col4" class="col_heading level0 col4" >2022-05</th>
#       <th id="T_f0b7e_level0_col5" class="col_heading level0 col5" >2022-06</th>
#       <th id="T_f0b7e_level0_col6" class="col_heading level0 col6" >2022-07</th>
#       <th id="T_f0b7e_level0_col7" class="col_heading level0 col7" >2022-08</th>
#       <th id="T_f0b7e_level0_col8" class="col_heading level0 col8" >2022-09</th>
#       <th id="T_f0b7e_level0_col9" class="col_heading level0 col9" >20

# %%
mu_p1_rs = cprs[["event_id", "month", "player1_army", "player1_game_result_cat", "player2_army"]].rename(columns={"player1_army": "army", "player2_army": "opponent", "player1_game_result_cat": "result"})
mu_p2_rs = cprs[["event_id", "month", "player2_army", "player2_game_result_cat", "player1_army"]].rename(columns={"player2_army": "army", "player1_army": "opponent", "player2_game_result_cat": "result"})

mu_rs = pd.concat([mu_p1_rs, mu_p2_rs], ignore_index=True)
mu_rs = mu_rs[mu_rs.month >= "2022-09"]

# mu_rs = mu_rs[mu_rs.army.isin(["Pathfinders", "Hunter Clade", "Intercession Squad"])]

mu_rs["both_bespoke"] = mu_rs.army.isin(bespoke_teams) & mu_rs.opponent.isin(bespoke_teams)
mu_rs = mu_rs[mu_rs.both_bespoke].groupby(["army", "opponent", "result"]).size().sort_values().reset_index()
mu_rs = mu_rs.rename(columns={0: "outcomes"})

# %%
mu_rs = mu_rs.pivot(index=["army", "opponent"], columns="result", values="outcomes").fillna(0).astype("int32")
mu_rs["matches"] = mu_rs.loss + mu_rs.tie + mu_rs.win
mu_rs["win_rate"] = mu_rs.win.astype("float64") / mu_rs.matches
mu_rs = mu_rs.reset_index()
mu_rs = mu_rs.pivot(index="army", columns="opponent", values="win_rate").fillna(0)


def _cc(val):
    if val == 0:
        color = "#ccc"
    elif val < 0.3:
        color = "red"
    elif val > 0.7:
        color = "green"
    else:
        color = "default"
        
    return 'color: %s' % color

mu_rs.style.format({c: '{:.0%}' for c in mu_rs.columns}).applymap(_cc)
# Out:
# <style type="text/css">
# #T_48e04_row0_col0, #T_48e04_row0_col1, #T_48e04_row0_col3, #T_48e04_row0_col6, #T_48e04_row0_col7, #T_48e04_row0_col8, #T_48e04_row0_col10, #T_48e04_row0_col11, #T_48e04_row0_col15, #T_48e04_row0_col16, #T_48e04_row0_col18, #T_48e04_row1_col0, #T_48e04_row1_col1, #T_48e04_row1_col2, #T_48e04_row1_col6, #T_48e04_row1_col8, #T_48e04_row1_col10, #T_48e04_row1_col11, #T_48e04_row1_col12, #T_48e04_row1_col13, #T_48e04_row1_col15, #T_48e04_row1_col18, #T_48e04_row2_col1, #T_48e04_row2_col3, #T_48e04_row2_col4, #T_48e04_row2_col6, #T_48e04_row2_col10, #T_48e04_row2_col11, #T_48e04_row2_col12, #T_48e04_row2_col13, #T_48e04_row2_col15, #T_48e04_row3_col2, #T_48e04_row3_col6, #T_48e04_row3_col11, #T_48e04_row3_col13, #T_48e04_row4_col1, #T_48e04_row4_col2, #T_48e04_row4_col4, #T_48e04_row4_col7, #T_48e04_row4_col8, #T_48e04_row4_col11, #T_48e04_row4_col13, #T_48e04_row4_col15, #T_48e04_row4_col17, #T_48e04_row4_col18, #T_48e04_row6_col1, #T_48e04_row6_col2, #T_48e04_row6_col3, #T_48e04_row6_col6, #T_48e04_row6_col7, #T_48e04_row6_col8, #T_48e04_row6_col10, #T_48e04_row6_col11, #T_48e04_row6_col12, #T_48e04_row6_col13, #T_48e04_row6_col14, #T_48e04_row6_col15, #T_48e04_row6_col16, #T_48e04_row6_col17, #T_48e04_row6_col18, #T_48e04_row7_col1, #T_48e04_row7_col4, #T_48e04_row7_col6, #T_48e04_row7_col7, #T_48e04_row7_col8, #T_48e04_row7_col10, #T_48e04_row7_col11, #T_48e04_row7_col13, #T_48e04_row7_col17, #T_48e04_row7_col18, #T_48e04_row8_col0, #T_48e04_row8_col1, #T_48e04_row8_col4, #T_48e04_row8_col6, #T_48e04_row8_col7, #T_48e04_row8_col8, #T_48e04_row8_col10, #T_48e04_row8_col11, #T_48e04_row8_col12, #T_48e04_row8_col13, #T_48e04_row8_col15, #T_48e04_row8_col16, #T_48e04_row8_col17, #T_48e04_row8_col18, #T_48e04_row10_col0, #T_48e04_row10_col1, #T_48e04_row10_col2, #T_48e04_row10_col6, #T_48e04_row10_col7, #T_48e04_row10_col10, #T_48e04_row10_col12, #T_48e04_row10_col13, #T_48e04_row10_col14, #T_48e04_row10_col15, #T_48e04_row10_col16, #T_48e04_row10_col17, #T_48e04_row10_col18, #T_48e04_row11_col0, #T_48e04_row11_col1, #T_48e04_row11_col2, #T_48e04_row11_col3, #T_48e04_row11_col4, #T_48e04_row11_col6, #T_48e04_row11_col7, #T_48e04_row11_col8, #T_48e04_row11_col10, #T_48e04_row11_col11, #T_48e04_row11_col12, #T_48e04_row11_col13, #T_48e04_row11_col15, #T_48e04_row11_col16, #T_48e04_row11_col17, #T_48e04_row11_col18, #T_48e04_row12_col1, #T_48e04_row12_col2, #T_48e04_row12_col6, #T_48e04_row12_col8, #T_48e04_row12_col10, #T_48e04_row12_col11, #T_48e04_row12_col12, #T_48e04_row12_col13, #T_48e04_row12_col14, #T_48e04_row12_col15, #T_48e04_row12_col16, #T_48e04_row12_col17, #T_48e04_row12_col18, #T_48e04_row13_col1, #T_48e04_row13_col2, #T_48e04_row13_col3, #T_48e04_row13_col4, #T_48e04_row13_col6, #T_48e04_row13_col7, #T_48e04_row13_col8, #T_48e04_row13_col10, #T_48e04_row13_col11, #T_48e04_row13_col12, #T_48e04_row13_col13, #T_48e04_row13_col14, #T_48e04_row13_col15, #T_48e04_row13_col16, #T_48e04_row14_col2, #T_48e04_row14_col6, #T_48e04_row14_col10, #T_48e04_row14_col12, #T_48e04_row14_col13, #T_48e04_row14_col14, #T_48e04_row14_col15, #T_48e04_row14_col18, #T_48e04_row15_col0, #T_48e04_row15_col1, #T_48e04_row15_col2, #T_48e04_row15_col6, #T_48e04_row15_col8, #T_48e04_row15_col10, #T_48e04_row15_col11, #T_48e04_row15_col12, #T_48e04_row15_col13, #T_48e04_row15_col14, #T_48e04_row15_col15, #T_48e04_row15_col16, #T_48e04_row15_col17, #T_48e04_row15_col18, #T_48e04_row16_col0, #T_48e04_row16_col6, #T_48e04_row16_col8, #T_48e04_row16_col10, #T_48e04_row16_col11, #T_48e04_row16_col12, #T_48e04_row16_col13, #T_48e04_row16_col14, #T_48e04_row16_col15, #T_48e04_row16_col16, #T_48e04_row16_col17, #T_48e04_row16_col18, #T_48e04_row17_col4, #T_48e04_row17_col6, #T_48e04_row17_col7, #T_48e04_row17_col8, #T_48e04_row17_col10, #T_48e04_row17_col11, #T_48e04_row17_col12, #T_48e04_row17_col15, #T_48e04_row17_col17, #T_48e04_row18_col1, #T_48e04_row18_col4, #T_48e04_row18_col5, #T_48e04_row18_col6, #T_48e04_row18_col7, #T_48e04_row18_col8, #T_48e04_ ...
#   color: default;
# }
# #T_48e04_row0_col2, #T_48e04_row0_col4, #T_48e04_row0_col5, #T_48e04_row0_col13, #T_48e04_row1_col3, #T_48e04_row1_col14, #T_48e04_row1_col16, #T_48e04_row1_col17, #T_48e04_row2_col17, #T_48e04_row2_col18, #T_48e04_row3_col14, #T_48e04_row3_col17, #T_48e04_row4_col5, #T_48e04_row4_col6, #T_48e04_row4_col10, #T_48e04_row4_col12, #T_48e04_row4_col14, #T_48e04_row4_col16, #T_48e04_row5_col1, #T_48e04_row5_col15, #T_48e04_row6_col5, #T_48e04_row6_col9, #T_48e04_row7_col2, #T_48e04_row7_col3, #T_48e04_row7_col5, #T_48e04_row7_col12, #T_48e04_row7_col14, #T_48e04_row7_col15, #T_48e04_row8_col2, #T_48e04_row8_col3, #T_48e04_row8_col5, #T_48e04_row8_col9, #T_48e04_row8_col14, #T_48e04_row10_col3, #T_48e04_row11_col5, #T_48e04_row11_col14, #T_48e04_row12_col3, #T_48e04_row13_col9, #T_48e04_row13_col17, #T_48e04_row13_col18, #T_48e04_row14_col0, #T_48e04_row14_col5, #T_48e04_row15_col3, #T_48e04_row16_col2, #T_48e04_row16_col7, #T_48e04_row17_col0, #T_48e04_row17_col5, #T_48e04_row17_col14, #T_48e04_row18_col3, #T_48e04_row18_col17 {
#   color: green;
# }
# #T_48e04_row0_col9, #T_48e04_row0_col12, #T_48e04_row0_col14, #T_48e04_row0_col17, #T_48e04_row1_col5, #T_48e04_row1_col9, #T_48e04_row2_col0, #T_48e04_row2_col2, #T_48e04_row2_col5, #T_48e04_row2_col7, #T_48e04_row2_col9, #T_48e04_row2_col14, #T_48e04_row2_col16, #T_48e04_row3_col0, #T_48e04_row3_col3, #T_48e04_row3_col4, #T_48e04_row3_col5, #T_48e04_row3_col7, #T_48e04_row3_col9, #T_48e04_row3_col10, #T_48e04_row3_col12, #T_48e04_row3_col15, #T_48e04_row3_col16, #T_48e04_row3_col18, #T_48e04_row4_col3, #T_48e04_row4_col9, #T_48e04_row5_col0, #T_48e04_row5_col2, #T_48e04_row5_col3, #T_48e04_row5_col4, #T_48e04_row5_col5, #T_48e04_row5_col6, #T_48e04_row5_col8, #T_48e04_row5_col9, #T_48e04_row5_col10, #T_48e04_row5_col11, #T_48e04_row5_col12, #T_48e04_row5_col13, #T_48e04_row5_col14, #T_48e04_row5_col16, #T_48e04_row5_col17, #T_48e04_row7_col9, #T_48e04_row7_col16, #T_48e04_row9_col0, #T_48e04_row9_col1, #T_48e04_row9_col2, #T_48e04_row9_col3, #T_48e04_row9_col4, #T_48e04_row9_col5, #T_48e04_row9_col6, #T_48e04_row9_col7, #T_48e04_row9_col8, #T_48e04_row9_col9, #T_48e04_row9_col10, #T_48e04_row9_col11, #T_48e04_row9_col12, #T_48e04_row9_col13, #T_48e04_row9_col14, #T_48e04_row9_col15, #T_48e04_row9_col16, #T_48e04_row9_col17, #T_48e04_row9_col18, #T_48e04_row10_col4, #T_48e04_row10_col5, #T_48e04_row10_col9, #T_48e04_row11_col9, #T_48e04_row12_col0, #T_48e04_row12_col4, #T_48e04_row12_col5, #T_48e04_row12_col7, #T_48e04_row12_col9, #T_48e04_row13_col5, #T_48e04_row14_col3, #T_48e04_row14_col9, #T_48e04_row15_col5, #T_48e04_row15_col9, #T_48e04_row16_col3, #T_48e04_row16_col5, #T_48e04_row16_col9, #T_48e04_row17_col2, #T_48e04_row17_col3, #T_48e04_row17_col9, #T_48e04_row18_col0, #T_48e04_row18_col2, #T_48e04_row18_col9 {
#   color: #ccc;
# }
# #T_48e04_row1_col4, #T_48e04_row1_col7, #T_48e04_row2_col8, #T_48e04_row3_col1, #T_48e04_row3_col8, #T_48e04_row4_col0, #T_48e04_row5_col7, #T_48e04_row5_col18, #T_48e04_row6_col0, #T_48e04_row6_col4, #T_48e04_row7_col0, #T_48e04_row10_col8, #T_48e04_row10_col11, #T_48e04_row13_col0, #T_48e04_row14_col1, #T_48e04_row14_col4, #T_48e04_row14_col7, #T_48e04_row14_col8, #T_48e04_row14_col11, #T_48e04_row14_col16, #T_48e04_row14_col17, #T_48e04_row15_col4, #T_48e04_row15_col7, #T_48e04_row16_col1, #T_48e04_row16_col4, #T_48e04_row17_col1, #T_48e04_row17_col13, #T_48e04_row17_col16, #T_48e04_row17_col18, #T_48e04_row18_col12, #T_48e04_row18_col13 {
#   color: red;
# }
# </style>
# <table id="T_48e04">
#   <thead>
#     <tr>
#       <th class="index_name level0" >opponent</th>
#       <th id="T_48e04_level0_col0" class="col_heading level0 col0" >Blooded Traitors</th>
#       <th id="T_48e04_level0_col1" class="col_heading level0 col1" >Corsair Voidscarred</th>
#       <th id="T_48e04_level0_col2" class="col_heading le
